# %%
import pandas as pd
from datetime import date, time, datetime

# %%
df= pd.read_csv(r"Registro_detallado_de_validaciones(4).csv", sep=",")
df.head()
# Out:
#   Fecha inicio servicio  Numero Servicio    Nombre y Apellido  \
# 0   2019/06/14 00:00:00                1  QUISPE GAMBOA CESAR
# 1   2019/06/14 00:00:00                1  QUISPE GAMBOA CESAR
# 2   2019/06/14 00:00:00                1  QUISPE GAMBOA CESAR
# 3   2019/06/14 00:00:00                1  QUISPE GAMBOA CESAR
# 4   2019/06/14 00:00:00                1  QUISPE GAMBOA CESAR
#
#      Fecha validacione Fecha y hora validacione  Numero del emplazamiento  \
# 0  2019/06/14 00:00:00      2019/06/14 13:13:53                     34104
# 1  2019/06/14 00:00:00      2019/06/14 13:14:06                     34104
# 2  2019/06/14 00:00:00      2019/06/14 13:14:12                     34104
# 3  2019/06/14 00:00:00      2019/06/14 13:14:16                     34104
# 4  2019/06/14 00:00:00      2019/06/14 13:14:21                     34104
#
#   PlacaBus Perfil Tarjeta  Num Linea     Nombre de la linea  \
# 0  ADJ-750        ANONIMO        301  301 - Tacna Garcilazo
# ...

# %%
df_General= df[['Num Linea','Parada','Desc Parada','Fecha y hora validacione','Numero de la tarjeta','Sentido Resumen']]
df_General.head()
# Out:
#    Num Linea  Parada Desc Parada Fecha y hora validacione  \
# 0        301     288    AMANCAES      2019/06/14 13:13:53
# 1        301     288    AMANCAES      2019/06/14 13:14:06
# 2        301     288    AMANCAES      2019/06/14 13:14:12
# 3        301     288    AMANCAES      2019/06/14 13:14:16
# 4        301     288    AMANCAES      2019/06/14 13:14:21
#
#    Numero de la tarjeta Sentido Resumen
# 0            3485497709              NS
# 1            3485497709              NS
# 2            3485497709              NS
# 3            3506243517              NS
# 4            3282143165              NS

# %%
df_General.groupby('Num Linea').count()
# Out:
#            Parada  Desc Parada  Fecha y hora validacione  \
# Num Linea
# 301         42329        42329                     42329
# 302         20833        20833                     20833
# 303         17532        17532                     17532
# 306         14457        14457                     14457
#
#            Numero de la tarjeta  Sentido Resumen
# Num Linea
# 301                       42329            42329
# 302                       20833            20833
# 303                       17532            17532
# 306                       14457            14457

# %%
df_General_301L=df_General[df_General['Num Linea']==301]
df_General_302L=df_General[df_General['Num Linea']==302]
df_General_303L=df_General[df_General['Num Linea']==303]
df_General_306L=df_General[df_General['Num Linea']==306]

# %%
df_General_306L.head()
# Out:
#      Num Linea  Parada  Desc Parada Fecha y hora validacione  \
# 574        306     467  24 DE JUNIO      2019/06/14 12:51:31
# 575        306     467  24 DE JUNIO      2019/06/14 12:51:51
# 576        306     467  24 DE JUNIO      2019/06/14 12:51:58
# 577        306     467  24 DE JUNIO      2019/06/14 12:52:03
# 578        306     467  24 DE JUNIO      2019/06/14 12:52:27
#
#      Numero de la tarjeta Sentido Resumen
# 574            3485166397              NS
# 575            3280326317              NS
# 576            3284374941              NS
# 577            3484998925              NS
# 578            3485542637              NS

# %%
df_General_301L['HORAN'] = df_General_301L['Fecha y hora validacione'].str.extract(r'(\d\d:\d\d:\d\d)')
df_General_302L['HORAN'] = df_General_302L['Fecha y hora validacione'].str.extract(r'(\d\d:\d\d:\d\d)')
df_General_303L['HORAN'] = df_General_303L['Fecha y hora validacione'].str.extract(r'(\d\d:\d\d:\d\d)')
df_General_306L['HORAN'] = df_General_306L['Fecha y hora validacione'].str.extract(r'(\d\d:\d\d:\d\d)')
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_3892\3207477295.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_General_301L['HORAN'] = df_General_301L['Fecha y hora validacione'].str.extract(r'(\d\d:\d\d:\d\d)')
# C:\Users\User\AppData\Local\Temp\ipykernel_3892\3207477295.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_General_302L['HORAN'] = df_General_302L['Fecha y hora validacione'].str.extract(r'(\d\d:\d\d:\d\d)')
# ...

# %%
df_General_306L.head()
# Out:
#      Num Linea  Parada  Desc Parada Fecha y hora validacione  \
# 574        306     467  24 DE JUNIO      2019/06/14 12:51:31
# 575        306     467  24 DE JUNIO      2019/06/14 12:51:51
# 576        306     467  24 DE JUNIO      2019/06/14 12:51:58
# 577        306     467  24 DE JUNIO      2019/06/14 12:52:03
# 578        306     467  24 DE JUNIO      2019/06/14 12:52:27
#
#      Numero de la tarjeta Sentido Resumen     HORAN
# 574            3485166397              NS  12:51:31
# 575            3280326317              NS  12:51:51
# 576            3284374941              NS  12:51:58
# 577            3484998925              NS  12:52:03
# 578            3485542637              NS  12:52:27

# %%
df_General_301L['HORANN'] = df_General_301L['HORAN'].str.extract('([0-9]+)')
df_General_302L['HORANN'] = df_General_302L['HORAN'].str.extract('([0-9]+)')
df_General_303L['HORANN'] = df_General_303L['HORAN'].str.extract('([0-9]+)')
df_General_306L['HORANN'] = df_General_306L['HORAN'].str.extract('([0-9]+)')
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_3892\84256709.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_General_301L['HORANN'] = df_General_301L['HORAN'].str.extract('([0-9]+)')
# C:\Users\User\AppData\Local\Temp\ipykernel_3892\84256709.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_General_302L['HORANN'] = df_General_302L['HORAN'].str.extract('([0-9]+)')
# C:\Users\User\AppData\Local\Temp\ipykernel_3892\84256709.py:3: SettingWithCopyWarning:
# ...

# %%
df_General_306L.head()
# Out:
#      Num Linea  Parada  Desc Parada Fecha y hora validacione  \
# 574        306     467  24 DE JUNIO      2019/06/14 12:51:31
# 575        306     467  24 DE JUNIO      2019/06/14 12:51:51
# 576        306     467  24 DE JUNIO      2019/06/14 12:51:58
# 577        306     467  24 DE JUNIO      2019/06/14 12:52:03
# 578        306     467  24 DE JUNIO      2019/06/14 12:52:27
#
#      Numero de la tarjeta Sentido Resumen     HORAN HORANN
# 574            3485166397              NS  12:51:31     12
# 575            3280326317              NS  12:51:51     12
# 576            3284374941              NS  12:51:58     12
# 577            3484998925              NS  12:52:03     12
# 578            3485542637              NS  12:52:27     12

# %%
df_General_301L.groupby('HORANN').count()
# Out:
#         Num Linea  Parada  Desc Parada  Fecha y hora validacione  \
# HORANN
# 00            439     439          439                       439
# 01             41      41           41                        41
# 02             39      39           39                        39
# 04             32      32           32                        32
# 05            595     595          595                       595
# 06           2112    2112         2112                      2112
# 07           3296    3296         3296                      3296
# 08           2678    2678         2678                      2678
# 09           1998    1998         1998                      1998
# 10           2114    2114         2114                      2114
# 11           2174    2174         2174                      2174
# 12           2314    2314         2314                      2314
# 13           2411    2411         2411                      2411
# ...

# %%
df_18pm_301L = df_General_301L[df_General_301L['HORANN'] == '17']
df_18pm_302L = df_General_302L[df_General_302L['HORANN'] == '17']
df_18pm_303L = df_General_303L[df_General_303L['HORANN'] == '17']
df_18pm_306L = df_General_306L[df_General_306L['HORANN'] == '17']

# %%
df_18pm_306L.head()
# Out:
#      Num Linea  Parada  Desc Parada Fecha y hora validacione  \
# 736        306     507  24 DE JUNIO      2019/06/14 17:10:25
# 737        306     507  24 DE JUNIO      2019/06/14 17:10:32
# 738        306     507  24 DE JUNIO      2019/06/14 17:10:42
# 739        306     507  24 DE JUNIO      2019/06/14 17:11:08
# 740        306     507  24 DE JUNIO      2019/06/14 17:11:16
#
#      Numero de la tarjeta Sentido Resumen     HORAN HORANN
# 736            2467521250              SN  17:10:25     17
# 737            3507847293              SN  17:10:32     17
# 738            3484806909              SN  17:10:42     17
# 739            2993969635              SN  17:11:08     17
# 740            3506168333              SN  17:11:16     17

# %%
df_18pm_306L.shape
# Out:
# (1015, 8)

# %%
Col_pivot_301L=pd.pivot_table(df_18pm_301L,index=['Sentido Resumen', 'Desc Parada','Parada','Num Linea'], aggfunc='count')
Col_pivot_302L=pd.pivot_table(df_18pm_302L,index=['Sentido Resumen', 'Desc Parada','Parada','Num Linea'], aggfunc='count')
Col_pivot_303L=pd.pivot_table(df_18pm_303L,index=['Sentido Resumen', 'Desc Parada','Parada','Num Linea'], aggfunc='count')
Col_pivot_306L=pd.pivot_table(df_18pm_306L,index=['Sentido Resumen', 'Desc Parada','Parada','Num Linea'], aggfunc='count')

# %%
Col_pivot_306L.head()
# Out:
#                                                    Fecha y hora validacione  \
# Sentido Resumen Desc Parada      Parada Num Linea
# NS              C. VALDERRAMA    469    306                               2
#                 CUBA             481    306                               1
#                 EDUARDO DIBOS    468    306                               3
#                 ESPAÑA           478    306                               3
#                 HUANCAVELICA 306 475    306                               5
#
#                                                    HORAN  HORANN  \
# Sentido Resumen Desc Parada      Parada Num Linea
# NS              C. VALDERRAMA    469    306            2       2
#                 CUBA             481    306            1       1
#                 EDUARDO DIBOS    468    306            3       3
#                 ESPAÑA           478    306            3       3
#                 HUANCAVELICA 306 475    306            5       5
#
# ...

# %%
df_18menos_301L = df_General_301L[(df_General_301L['HORANN'] < '17') | (df_General_301L['HORANN'] > '17')]
df_18menos_302L = df_General_302L[(df_General_302L['HORANN'] < '17') | (df_General_302L['HORANN'] > '17')]
df_18menos_303L = df_General_303L[(df_General_303L['HORANN'] < '17') | (df_General_303L['HORANN'] > '17')]
df_18menos_306L = df_General_306L[(df_General_306L['HORANN'] < '17') | (df_General_306L['HORANN'] > '17')]

# %%
df_18menos_306L.head()
# Out:
#      Num Linea  Parada  Desc Parada Fecha y hora validacione  \
# 574        306     467  24 DE JUNIO      2019/06/14 12:51:31
# 575        306     467  24 DE JUNIO      2019/06/14 12:51:51
# 576        306     467  24 DE JUNIO      2019/06/14 12:51:58
# 577        306     467  24 DE JUNIO      2019/06/14 12:52:03
# 578        306     467  24 DE JUNIO      2019/06/14 12:52:27
#
#      Numero de la tarjeta Sentido Resumen     HORAN HORANN
# 574            3485166397              NS  12:51:31     12
# 575            3280326317              NS  12:51:51     12
# 576            3284374941              NS  12:51:58     12
# 577            3484998925              NS  12:52:03     12
# 578            3485542637              NS  12:52:27     12

# %%
df_merge_301L = pd.merge(df_18pm_301L, df_18menos_301L, on=['Numero de la tarjeta'], how='inner', indicator=True)
df_merge_302L = pd.merge(df_18pm_302L, df_18menos_302L, on=['Numero de la tarjeta'], how='inner', indicator=True)
df_merge_303L = pd.merge(df_18pm_303L, df_18menos_303L, on=['Numero de la tarjeta'], how='inner', indicator=True)
df_merge_306L = pd.merge(df_18pm_306L, df_18menos_306L, on=['Numero de la tarjeta'], how='inner', indicator=True)

# %%
df_merge_306L.head()
# Out:
#    Num Linea_x  Parada_x Desc Parada_x Fecha y hora validacione_x  \
# 0          306       507   24 DE JUNIO        2019/06/14 17:10:32
# 1          306       507   24 DE JUNIO        2019/06/14 17:11:08
# 2          306       507   24 DE JUNIO        2019/06/14 17:11:16
# 3          306       507   24 DE JUNIO        2019/06/14 17:11:24
# 4          306       507   24 DE JUNIO        2019/06/14 17:11:24
#
#    Numero de la tarjeta Sentido Resumen_x   HORAN_x HORANN_x  Num Linea_y  \
# 0            3507847293                SN  17:10:32       17          306
# 1            2993969635                SN  17:11:08       17          306
# 2            3506168333                SN  17:11:16       17          306
# 3            3485506909                SN  17:11:24       17          306
# 4            3485506909                SN  17:11:24       17          306
#
#    Parada_y  Desc Parada_y Fecha y hora validacione_y Sentido Resumen_y  \
# ...

# %%
df_merge_301L['LOGICO'] = ''
df_merge_301L.loc[df_merge_301L['Desc Parada_x'] == df_merge_301L['Desc Parada_y'], 'LOGICO'] = '0'
df_merge_301L.loc[df_merge_301L['Desc Parada_x'] != df_merge_301L['Desc Parada_y'], 'LOGICO'] = '1'

# %%
df_merge_302L['LOGICO'] = ''
df_merge_302L.loc[df_merge_302L['Desc Parada_x'] == df_merge_302L['Desc Parada_y'], 'LOGICO'] = '0'
df_merge_302L.loc[df_merge_302L['Desc Parada_x'] != df_merge_302L['Desc Parada_y'], 'LOGICO'] = '1'

# %%
df_merge_303L['LOGICO'] = ''
df_merge_303L.loc[df_merge_303L['Desc Parada_x'] == df_merge_303L['Desc Parada_y'], 'LOGICO'] = '0'
df_merge_303L.loc[df_merge_303L['Desc Parada_x'] != df_merge_303L['Desc Parada_y'], 'LOGICO'] = '1'

# %%
df_merge_306L['LOGICO'] = ''
df_merge_306L.loc[df_merge_306L['Desc Parada_x'] == df_merge_306L['Desc Parada_y'], 'LOGICO'] = '0'
df_merge_306L.loc[df_merge_306L['Desc Parada_x'] != df_merge_306L['Desc Parada_y'], 'LOGICO'] = '1'

# %%
df_merge_306L.head()
# Out:
#    Num Linea_x  Parada_x Desc Parada_x Fecha y hora validacione_x  \
# 0          306       507   24 DE JUNIO        2019/06/14 17:10:32
# 1          306       507   24 DE JUNIO        2019/06/14 17:11:08
# 2          306       507   24 DE JUNIO        2019/06/14 17:11:16
# 3          306       507   24 DE JUNIO        2019/06/14 17:11:24
# 4          306       507   24 DE JUNIO        2019/06/14 17:11:24
#
#    Numero de la tarjeta Sentido Resumen_x   HORAN_x HORANN_x  Num Linea_y  \
# 0            3507847293                SN  17:10:32       17          306
# 1            2993969635                SN  17:11:08       17          306
# 2            3506168333                SN  17:11:16       17          306
# 3            3485506909                SN  17:11:24       17          306
# 4            3485506909                SN  17:11:24       17          306
#
#    Parada_y  Desc Parada_y Fecha y hora validacione_y Sentido Resumen_y  \
# ...

# %%
with pd.ExcelWriter('py_salidaCORREDOR-TGA_2019-06-14-17pm-T.xlsx') as writer:
##    df_merge_301L.to_excel(writer, index=False, sheet_name='301L')
##    df_merge_302L.to_excel(writer, index=False, sheet_name='302L')
##    df_merge_303L.to_excel(writer, index=False, sheet_name='303L')
##    df_merge_306L.to_excel(writer, index=False, sheet_name='306L')
    Col_pivot_301L.to_excel(writer, index= True, sheet_name='pivot_301L')
    Col_pivot_302L.to_excel(writer, index= True, sheet_name='pivot_302L')
    Col_pivot_303L.to_excel(writer, index= True, sheet_name='pivot_303L')
    Col_pivot_306L.to_excel(writer, index= True, sheet_name='pivot_306L')
